# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/someone/data/sales.csv')

# %%
sample = df.sample(100)

# %%
import os
api_key = os.environ['API_KEY']

# %%
from datetime import datetime
print(f"Generated at: {datetime.now()}")
