# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/sales.csv')

# %%
# Bug: Column name is lowercase 'revenue', not 'Revenue'
total_sales = df['Revenue'].sum()
# Out:
# KeyError: 'Revenue'

# %%
# Bug: Variable is 'df', not 'data'
avg_cost = data['cost'].mean()
# Out:
# NameError: name 'data' is not defined

# %%
# Bug: date is string, need to convert first
df['days_ago'] = pd.Timestamp.now() - df['date']
# Out:
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
# This cell should calculate profit margin but has a division error waiting
df['profit'] = df['revenue'] - df['cost']
df['margin'] = df['profit'] / df['revnue']  # Typo: 'revnue' instead of 'revenue'
